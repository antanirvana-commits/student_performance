# %% [markdown]
# # Student Performance Risk Classifier
# Notebook skeleton for EDA, preprocessing, and modeling.

# %%
import pandas as pd
from pathlib import Path
base = Path.cwd().parents[0]
df = pd.read_csv(base / "data/raw/StudentPerformanceFactors.csv")
df.head()

# %%
df["Performance_Target"] = (df["Exam_Score"] >= 70).astype(int)
df["Performance_Target"].value_counts(normalize=True)

# %%
df.isna().sum().sort_values(ascending=False).head(10)

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Hours_Studied"], df["Exam_Score"], alpha=0.3)
plt.xlabel("Hours_Studied")
plt.ylabel("Exam_Score")
plt.show()

# %%
from src.train_model import main
main()
